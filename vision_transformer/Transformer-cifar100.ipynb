# %%
print("============查看GPU信息================")
# !/opt/bin/nvidia-smi
print("==============查看pytorch版本==============")
import torch
print(torch.__version__)
print("============查看虚拟机硬盘容量================")
# !df -lh
print("============查看cpu配置================")
# !cat /proc/cpuinfo | grep model\ name
print("=============查看内存容量===============")
# !cat /proc/meminfo | grep MemTotal
# Out:
# ============查看GPU信息================
# Sat Jun  4 03:12:21 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd /content/drive/MyDrive/CV/AlexNet_data_agumentation
# Out:
# /content/drive/MyDrive/CV/AlexNet_data_agumentation

# %%
# !python train.py
# Out:
# using cuda:0 device.
# Using 4 dataloader workers every process
# Files already downloaded and verified
# Files already downloaded and verified
# using 50000 images for training, 10000 images for validation.
# Number of parameters: 14.79M
# train epoch[1/100] loss:4.352:  34% 537/1563 [00:25<00:49, 20.87it/s]
# Traceback (most recent call last):
#   File "train.py", line 151, in <module>
#     main()
#   File "train.py", line 78, in main
#     mix_images, mix_labels, lam = mixup_data(images, labels, 0.5)
#   File "/content/drive/MyDrive/CV/AlexNet_data_agumentation/utils/data.py", line 25, in mixup_data
#     mixup_images = torch.zeros([images.shape[0], 3, 224, 224])
# KeyboardInterrupt

# %%
# %cd /content/drive/MyDrive/CV/vision_transformer
# Out:
# /content/drive/MyDrive/CV/vision_transformer

# %%
# !rm -r /content/drive/MyDrive/CV/vision_transformer/tensorboard/Transformer

# %%
# !python train.py
# Out:
# using cuda device.
# Using 4 dataloader workers every process
# Files already downloaded and verified
# Files already downloaded and verified
# Number of parameters: 14.79M
# [train epoch 1] loss: 4.128, acc: 0.077: 100% 6250/6250 [04:21<00:00, 23.86it/s]
# [valid epoch 1] loss: 3.698, acc: 0.133: 100% 1250/1250 [00:20<00:00, 61.91it/s]
# [train epoch 2] loss: 3.711, acc: 0.131: 100% 6250/6250 [04:22<00:00, 23.77it/s]
# [valid epoch 2] loss: 3.555, acc: 0.151: 100% 1250/1250 [00:19<00:00, 62.77it/s]
# [train epoch 3] loss: 3.569, acc: 0.156: 100% 6250/6250 [04:22<00:00, 23.79it/s]
# [valid epoch 3] loss: 3.360, acc: 0.190: 100% 1250/1250 [00:19<00:00, 62.84it/s]
# [train epoch 4] loss: 3.467, acc: 0.174: 100% 6250/6250 [04:22<00:00, 23.85it/s]
# [valid epoch 4] loss: 3.325, acc: 0.206: 100% 1250/1250 [00:20<00:00, 62.16it/s]
# [train epoch 5] loss: 3.392, acc: 0.187: 100% 6250/6250 [04:22<00:00, 23.77it/s]
# ...
